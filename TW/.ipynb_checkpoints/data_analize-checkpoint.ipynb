# %%
import pandas as pd

# %%
data = pd.read_csv("outputData.csv")
data
# Out:
#         BUFFER_SIZE       P/C   SIZE  PK_CONFIG  FAIR_BUFFER  \
# 0             10000  CONSUMER      1        100         True
# 1             10000  CONSUMER      2        100         True
# 2             10000  CONSUMER      3        100         True
# 3             10000  CONSUMER      4        100         True
# 4             10000  CONSUMER      5        100         True
# ...             ...       ...    ...        ...          ...
# 434741       100000  PRODUCER  49962       1000        False
# 434742       100000  PRODUCER  49966       1000        False
# 434743       100000  PRODUCER  49972       1000        False
# 434744       100000  PRODUCER  49991       1000        False
# 434745       100000  PRODUCER  49999       1000        False
#
#         RANDOMIZATION_OPTION_NORMAL  COUNTER
# 0                              True       20
# 1                              True        7
# 2                              True       10
# 3                              True       10
# ...

# %%
data.groupby(["BUFFER_SIZE", "P/C", "PK_CONFIG",  "RANDOMIZATION_OPTION_NORMAL","FAIR_BUFFER",]).count()
# Out:
#                                                                          SIZE  \
# BUFFER_SIZE P/C      PK_CONFIG RANDOMIZATION_OPTION_NORMAL FAIR_BUFFER
# 10000       CONSUMER 100       False                       False         4958
#                                                            True          4971
#                                True                        False         4937
#                                                            True          4997
#                      1000      False                       False         4358
#                                                            True          4993
#                                True                        False         4342
#                                                            True          4999
#             PRODUCER 100       False                       False         4955
#                                                            True          4972
# ...

# %%
pd.options.mode.chained_assignment = None
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
def draw_plot(config, data):
    x = []
    y = []
    for i,j in data.items():
        x.append(str(i))
        y.append(j)
    plt.scatter(x,y)
#     plt.figure(figsize=(10,5))
    plt.show()
    
grouped_data = data.groupby(["BUFFER_SIZE", "P/C", "PK_CONFIG",  "RANDOMIZATION_OPTION_NORMAL","FAIR_BUFFER",])
for group,data_for_group in grouped_data:
    print(f"Buffer size is {group[0]}, {group[1]}, number of {group[1]}s is {group[2]}, normal randomization: {group[3]}, fair buffer: {group[4]}")
    min_size = data_for_group['SIZE'].min()
    max_size = data_for_group['SIZE'].max()
    interval = 100
    if(max_size > 5000):
        interval = 1000
    data_for_group['bin'] = pd.cut(data_for_group["SIZE"], [x for x in range(0, max_size+99, interval)])
    a = data_for_group.groupby('bin')["COUNTER"].sum()
    a.plot.box()
    plt.show()
    print()
    draw_plot(group, a)
# Out:
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 100, normal randomization: False, fair buffer: False
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 100, normal randomization: False, fair buffer: True
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 100, normal randomization: True, fair buffer: False
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 100, normal randomization: True, fair buffer: True
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 1000, normal randomization: False, fair buffer: False
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 1000, normal randomization: False, fair buffer: True
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 1000, normal randomization: True, fair buffer: False
# Buffer size is 10000, CONSUMER, number of CONSUMERs is 1000, normal randomization: True, fair buffer: True
# Buffer size is 10000, PRODUCER, number of PRODUCERs is 100, normal randomization: False, fair buffer: False
# ...
